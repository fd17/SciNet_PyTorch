# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import random
from matplotlib import pyplot as plt
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from models import SciNet
from utils import target_loss 
device = torch.device("cuda:0")

# %%
# Setup scinet model with 3 latent neurons
scinet = SciNet(50,1,3,64)

# Load and prepare training data
inputs = torch.Tensor(np.load("training_data/inputs.npy"))
outputs = torch.Tensor(np.load("training_data/outputs.npy"))
traindata = TensorDataset(inputs, outputs)
dataloader = DataLoader(traindata, batch_size=256,shuffle=True, num_workers=1)

# %%
# Training setup
SAVE_PATH = "trained_models/scinet1.dat"
N_EPOCHS = 100
optimizer = optim.Adam(scinet.parameters())
hist_error = []
hist_loss = []
beta = 0.5

# Training loop
for epoch in range(N_EPOCHS):  
    epoch_error = []
    epoch_loss = []
    for i_batch, minibatch in enumerate(dataloader):

        inputs, outputs = minibatch
        optimizer.zero_grad()
        pred = scinet.forward(inputs)
        
        loss = target_loss(pred, outputs) + beta * scinet.kl_loss
        loss.backward()
        optimizer.step()
        error = torch.mean(torch.sqrt((pred[:,0]-outputs)**2)).detach().numpy()
        epoch_error.append(error)
        epoch_loss.append(loss.data.detach().numpy())
    hist_error.append(np.mean(epoch_error))
    hist_loss.append(np.mean(epoch_loss))
    print("Epoch %d -- loss %f, RMS error %f " % (epoch+1, hist_loss[-1], hist_error[-1]))
    
torch.save(scinet.state_dict(), SAVE_PATH)
print("Model saved to %s" % SAVE_PATH)
# Out:
# Epoch 1 -- loss 16.593849, RMS error 0.170585
# Epoch 2 -- loss 7.636801, RMS error 0.126207
# Epoch 3 -- loss 3.514126, RMS error 0.089356
# Epoch 4 -- loss 2.309311, RMS error 0.074846
# Epoch 5 -- loss 2.016938, RMS error 0.070563
# Epoch 6 -- loss 1.833562, RMS error 0.067729
# Epoch 7 -- loss 1.579440, RMS error 0.063346
# Epoch 8 -- loss 1.369459, RMS error 0.059893
# Epoch 9 -- loss 1.219574, RMS error 0.057151
# Epoch 10 -- loss 1.110448, RMS error 0.054878
# Epoch 11 -- loss 1.035475, RMS error 0.053298
# Epoch 12 -- loss 0.981782, RMS error 0.052065
# Epoch 13 -- loss 0.923182, RMS error 0.050650
# Epoch 14 -- loss 0.887896, RMS error 0.049872
# Epoch 15 -- loss 0.822554, RMS error 0.048091
# Epoch 16 -- loss 0.772634, RMS error 0.046866
# Epoch 17 -- loss 0.727436, RMS error 0.045767
# Epoch 18 -- loss 0.701246, RMS error 0.045131
# Epoch 19 -- loss 0.680254, RMS error 0.044629
# Epoch 20 -- loss 0.651239, RMS error 0.043706
# Epoch 21 -- loss 0.636901, RMS error 0.043414
# Epoch 22 -- loss 0.620121, RMS error 0.042910
# Epoch 23 -- loss 0.608091, RMS error 0.042621
# Epoch 24 -- loss 0.589438, RMS error 0.041901
# Epoch 25 -- loss 0.578824, RMS error 0.041355
# Epoch 26 -- loss 0.551785, RMS error 0.040174
# Epoch 27 -- loss 0.544762, RMS error 0.039836
# Epoch 28 -- loss 0.529921, RMS error 0.039121
# Epoch 29 -- loss 0.509624, RMS error 0.038085
# Epoch 30 -- loss 0.493589, RMS error 0.037351
# Epoch 31 -- loss 0.485189, RMS error 0.036987
# Epoch 32 -- loss 0.470932, RMS error 0.036386
# Epoch 33 -- loss 0.468985, RMS error 0.036232
# Epoch 34 -- loss 0.450339, RMS error 0.035455
# Epoch 35 -- loss 0.458549, RMS error 0.035783
# Epoch 36 -- loss 0.446546, RMS error 0.035288
# Epoch 37 -- loss 0.441189, RMS error 0.035100
# Epoch 38 -- loss 0.437884, RMS error 0.034907
# Epoch 39 -- loss 0.423831, RMS error 0.034348
# Epoch 40 -- loss 0.425234, RMS error 0.034454
# Epoch 41 -- loss 0.416889, RMS error 0.034089
# Epoch 42 -- loss 0.411108, RMS error 0.033850
# Epoch 43 -- loss 0.412022, RMS error 0.033876
# Epoch 44 -- loss 0.412861, RMS error 0.034017
# Epoch 45 -- loss 0.397741, RMS error 0.033249
# Epoch 46 -- loss 0.392555, RMS error 0.033049
# Epoch 47 -- loss 0.390918, RMS error 0.032958
# Epoch 48 -- loss 0.385960, RMS error 0.032918
# Epoch 49 -- loss 0.378100, RMS error 0.032577
# Epoch 50 -- loss 0.361787, RMS error 0.032057
# Epoch 51 -- loss 0.365247, RMS error 0.032057
# Epoch 52 -- loss 0.346374, RMS error 0.031306
# Epoch 53 -- loss 0.348111, RMS error 0.031491
# Epoch 54 -- loss 0.334088, RMS error 0.030865
# Epoch 55 -- loss 0.346827, RMS error 0.031452
# Epoch 56 -- loss 0.330738, RMS error 0.030651
# Epoch 57 -- loss 0.332447, RMS error 0.030711
# Epoch 58 -- loss 0.317088, RMS error 0.029993
# Epoch 59 -- loss 0.316335, RMS error 0.030092
# Epoch 60 -- loss 0.321695, RMS error 0.030237
# Epoch 61 -- loss 0.314657, RMS error 0.029985
# Epoch 62 -- loss 0.305794, RMS error 0.029624
# Epoch 63 -- loss 0.317774, RMS error 0.030189
# Epoch 64 -- loss 0.300247, RMS error 0.029361
# Epoch 65 -- loss 0.310125, RMS error 0.029742
# Epoch 66 -- loss 0.302243, RMS error 0.029467
# Epoch 67 -- loss 0.299969, RMS error 0.029254
# Epoch 68 -- loss 0.295643, RMS error 0.029266
# Epoch 69 -- loss 0.295856, RMS error 0.029190
# Epoch 70 -- loss 0.296531, RMS error 0.029169
# Epoch 71 -- loss 0.292878, RMS error 0.028996
# Epoch 72 -- loss 0.289774, RMS error 0.028874
# Epoch 73 -- loss 0.289380, RMS error 0.028854
# Epoch 74 -- loss 0.286199, RMS error 0.028743
# Epoch 75 -- loss 0.283837, RMS error 0.028641
# Epoch 76 -- loss 0.282150, RMS error 0.028496
# Epoch 77 -- loss 0.287284, RMS error 0.028798
# Epoch 78 -- loss 0.283223, RMS error 0.028635
# Epoch 79 -- loss 0.282383, RMS error 0.028560
# Epoch 80 -- loss 0.281219, RMS error 0.028502
# Epoch 81 -- loss 0.270874, RMS error 0.027974
# Epoch 82 -- loss 0.276814, RMS error 0.028231
# Epoch 83 -- loss 0.275879, RMS error 0.028192
# Epoch 84 -- loss 0.267819, RMS error 0.027927
# Epoch 85 -- loss 0.275687, RMS error 0.028143
# Epoch 86 -- loss 0.273332, RMS error 0.028121
# Epoch 87 -- loss 0.273418, RMS error 0.028103
# Epoch 88 -- loss 0.273801, RMS error 0.028127
# Epoch 89 -- loss 0.263689, RMS error 0.027698
# Epoch 90 -- loss 0.278303, RMS error 0.028390
# Epoch 91 -- loss 0.264742, RMS error 0.027746
# Epoch 92 -- loss 0.264063, RMS error 0.027678
# Epoch 93 -- loss 0.262945, RMS error 0.027601
# Epoch 94 -- loss 0.262139, RMS error 0.027654
# Epoch 95 -- loss 0.267290, RMS error 0.027799
# Epoch 96 -- loss 0.265579, RMS error 0.027784
# Epoch 97 -- loss 0.261020, RMS error 0.027436
# Epoch 98 -- loss 0.253766, RMS error 0.027223
# Epoch 99 -- loss 0.260670, RMS error 0.027476
# Epoch 100 -- loss 0.262041, RMS error 0.027690
# Model saved to trained_models/scinet1.dat

# %%
# Plot some training history data
# %matplotlib inline 
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
ax1.plot(hist_error)
ax1.set_ylabel("Amplitude RMSE")
ax2.plot(hist_loss)
ax2.set_ylabel("Loss")
ax2.set_xlabel("Epoch")
plt.show()
